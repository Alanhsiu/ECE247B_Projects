# %% [markdown]
# # Reinforcement Learning Bonus: DDPG

# %% [markdown]
# - As before, please do not modify the folder architecture and do not rename some of the files.
#
# - You will need to fill in the model.py and DDPG.py to solve the DoublePendulum environment.
# - Because this is a bonus, there will be no test cases.
# - This entire part will be worth 5 points of extra credit for project 4, and will be due on the same day as project 4.
#
# To avoid pain with installation and model training, we strongly recommend you to use Colab for this project. DO NOT use Windows for this project.

# %% [markdown]
# ## Set up

# %%
# mount it if you use Colab
# from google.colab import drive

# drive.mount("/content/drive")

# %%
# TODO: change the dir to your folder
# %cd /content/drive/MyDrive/YOUR_FOLDER_NAME
# %cd /home/b09901066/ECE247B_Projects/project4/
# Out:
# /home/b09901066/ECE247B_Projects/project4
# /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %load_ext autoreload
# %autoreload 2
# %env MUJOCO_GL=egl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: MUJOCO_GL=egl

# %%
# !pip install numpy torch wandb swig gymnasium[mujoco] matplotlib termcolor
# Out:
# Requirement already satisfied: numpy in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: torch in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (2.6.0+cu124)
# Requirement already satisfied: wandb in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (0.26.1)
# Requirement already satisfied: swig in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (4.4.1)
# Requirement already satisfied: matplotlib in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (3.10.9)
# Requirement already satisfied: termcolor in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (3.3.0)
# Requirement already satisfied: gymnasium[mujoco] in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: filelock in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (2026.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: click>=8.0.1 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from wandb) (8.3.3)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from wandb) (3.1.50)
# Requirement already satisfied: packaging in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from wandb) (26.0)
# Requirement already satisfied: platformdirs in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from wandb) (4.9.6)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from wandb) (7.34.1)
# Requirement already satisfied: pydantic<3 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from wandb) (2.13.3)
# Requirement already satisfied: pyyaml in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from wandb) (2.33.1)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from wandb) (2.59.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from pydantic<3->wandb) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2026.4.22)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from gymnasium[mujoco]) (3.1.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from gymnasium[mujoco]) (0.0.6)
# Collecting mujoco>=2.1.5 (from gymnasium[mujoco])
#   Downloading mujoco-3.8.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (42 kB)
# Collecting imageio>=2.14.1 (from gymnasium[mujoco])
#   Downloading imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=8 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.3)
# Collecting absl-py (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting etils[epath] (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading etils-1.13.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting pyopengl (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading pyopengl-3.1.10-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six>=1.5 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting importlib_resources (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting zipp (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading zipp-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/b09901066/miniconda3/envs/minigpt/lib/python3.10/site-packages (from jinja2->torch) (3.0.3)
# Downloading imageio-2.37.3-py3-none-any.whl (317 kB)
# Downloading mujoco-3.8.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 21.6 MB/s  0:00:00 eta 0:00:01
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading etils-1.13.0-py3-none-any.whl (170 kB)
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl (243 kB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading pyopengl-3.1.10-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 11.9 MB/s  0:00:00 eta 0:00:01
# Downloading zipp-4.1.0-py3-none-any.whl (10 kB)
# Installing collected packages: pyopengl, glfw, zipp, importlib_resources, imageio, etils, absl-py, mujoco
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [mujoco]2m7/8 [mujoco]]b_resources]
# Successfully installed absl-py-2.4.0 etils-1.13.0 glfw-2.10.0 imageio-2.37.3 importlib_resources-7.1.0 mujoco-3.8.1 pyopengl-3.1.10 zipp-4.1.0

# %%
from utils import *

# %% [markdown]
# ## Introduction to the Environment
# We will be training a DDPG agent to solve the DoublePendulum environment. The DoublePendulum environment is a classic control problem where the goal is to balance a double pendulum on a cart.
# #### Action Space
# The agent can apply a force to the cart in the range of -1 to 1. This is a continuous action space.
# #### Observation Space
# The observation space is a 9 dimensional vector. The first 1 is the position of the cart, the next 4 are the cosines and sins of different angles of the double pendulum, and the next 3 are the velocities of the cart and the pendulum, and the final 1 is the constrain forces on the cart. You can find more information about these constraint forces [here](https://homes.cs.washington.edu/~todorov/papers/TodorovICRA14.pdf)
# #### Reward
# The reward can be decomposed into 3 parts. The first part is an alive bonus that pays +10 for every time step the second pendulum is upright. There are 2 penalty terms, one for the tip of the second pendulum moving too much, and another for the cart moving too fast.
#
# You can find more information about the environment [here](https://gymnasium.farama.org/environments/mujoco/inverted_double_pendulum/)
#
# First let us visualize the game and understand the environment.

# %%
import gymnasium as gym
import numpy as np

env = gym.make("InvertedDoublePendulum-v5")
env.np_random = np.random.RandomState(42)

eval_env = gym.make("InvertedDoublePendulum-v5", render_mode="rgb_array")
eval_env.np_random = np.random.RandomState(42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/minigpt/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_env.py:11
#      10 try:
# ---> 11     import mujoco
#      12 except ImportError as e:
#
# ModuleNotFoundError: No module named 'mujoco'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[11], line 4
#       1 import gymnasium as gym
#       2 import numpy as np
# ----> 4 env = gym.make("InvertedDoublePendulum-v5")
#       5 env.np_random = np.random.RandomState(42)
#       7 eval_env = gym.make("InvertedDoublePendulum-v5", render_mode="rgb_array")
#
# File ~/miniconda3/envs/minigpt/lib/python3.10/site-packages/gymnasium/envs/registration.py:697, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     694     env_creator = env_spec.entry_point
#     695 else:
#     696     # Assume it's a string
# --> 697     env_creator = load_env_creator(env_spec.entry_point)
#     699 # Determine if to use the rendering
#     700 render_modes: list[str] | None = None
#
# File ~/miniconda3/envs/minigpt/lib/python3.10/site-packages/gymnasium/envs/registration.py:545, in load_env_creator(name)
#     536 """Loads an environment with name of style ``"(import path):(environment name)"`` and returns the environment creation function, normally the environment class type.
#     537
#     538 Args:
#    (...)
#     542     The environment constructor for the given environment name.
#     543 """
#     544 mod_name, attr_name = name.split(":")
# --> 545 mod = importlib.import_module(mod_name)
#     546 fn = getattr(mod, attr_name)
#     547 return fn
#
# File ~/miniconda3/envs/minigpt/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:992, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/minigpt/lib/python3.10/site-packages/gymnasium/envs/mujoco/__init__.py:1
# ----> 1 from gymnasium.envs.mujoco.mujoco_env import MujocoEnv
#       2 from gymnasium.envs.mujoco.mujoco_rendering import MujocoRenderer
#       4 __all__ = ["MujocoEnv", "MujocoRenderer"]
#
# File ~/miniconda3/envs/minigpt/lib/python3.10/site-packages/gymnasium/envs/mujoco/mujoco_env.py:13
#      11     import mujoco
#      12 except ImportError as e:
# ---> 13     raise error.DependencyNotInstalled(
#      14         'MuJoCo is not installed, run `pip install "gymnasium[mujoco]"`'
#      15     ) from e
#      18 DEFAULT_SIZE = 480
#      21 def expand_model_path(model_path: str) -> str:
#
# DependencyNotInstalled: MuJoCo is not installed, run `pip install "gymnasium[mujoco]"`

# %%
from IPython.display import HTML

frames = []
s, _ = eval_env.reset()

while True:
    a = eval_env.action_space.sample()
    s, r, terminated, truncated, _ = eval_env.step(a)
    frames.append(eval_env.render())
    if terminated or truncated:
        break

anim = animate(frames)
HTML(anim.to_jshtml())

# %% [markdown]
# ## Model (1 point)
# Because the inputs to the model is a 9 dimensional vector, we will use a MLP. Specifically we will follow the architecture in the DDPG paper. For DDPG we have both an Actor and a Critic. The Actor is responsible for selecting the action, and the Critic is responsible for evaluating the action.
# #### Actor
# The Actor is a 3 layer MLP:
# - Layer 1: 400 units, ReLU activation, Fan-in weight initialization, ie each weight is initialized with a uniform distribution in the range of -1/sqrt(fan_in) to 1/sqrt(fan_in)
# - Layer 2: 300 units, ReLU activation, Fan-in weight initialization, ie each weight is initialized with a uniform distribution in the range of -1/sqrt(fan_in) to 1/sqrt(fan_in)
# - Layer 3: 1 unit, tanh activation, intialized with uniform weights in the range of -0.003 to 0.003
# #### Critic
# The Critic is a 3 layer MLP:
# - Layer 1: 400 units, ReLU activation, Fan-in weight initialization, ie each weight is initialized with a uniform distribution in the range of -1/sqrt(fan_in) to 1/sqrt(fan_in)
# - Layer 2: 300 units, ReLU activation, Fan-in weight initialization, ie each weight is initialized with a uniform distribution in the range of -1/sqrt(fan_in) to 1/sqrt(fan_in). Input is the concatenation of the 400 dimension embedding from the state, and the action taken.
# - Layer 3: 1 unit, intialized with uniform weights in the range of -0.003 to 0.003

# %%
import model

# %% [markdown]
# ## Exploration (1 point)
# Because DDPG is an off policy algorithm, we will use a noise process to encourage exploration. Specifically we will use the Ornstein-Uhlenbeck process. The Ornstein-Uhlenbeck process is a stochastic process that generates temporally correlated noise. The process is defined by the following stochastic differential equation:
# $$dx_t = \theta(\mu - x_t)dt + \sigma dW_t$$
# Where $\theta$ is the rate of mean reversion, $\mu$ is the long run mean of the process, $\sigma$ is the volatility of the process, and $W_t$ is a Wiener process. We can discretize this process to get the following:
# $$x_{t+1} = x_t + \theta(\mu - x_t)dt + \sigma \sqrt{dt}\mathcal{N}(0,1)$$
# Where $N(0,1)$ is a sample from the standard normal distribution. We will asume that our steps are of unit length, so we can simplify this to:
# $$x_{t+1} = x_t + \theta(\mu - x_t) + \sigma \mathcal{N}(0,1)$$
# We will use $\theta = 0.15$, $\mu = 0$, and $\sigma = 0.2$. We will add this to our action in the following way
# $$a_t = \min(\max(\mu(s_t) + x_t, -1), 1)$$
# Where $a_t$ is the action taken by the agent, $\mu(s_t)$ is the action selected by the actor, and $x_t$ is the noise generated by the Ornstein-Uhlenbeck process.
# Please implement the `OU_Noise` class in DDPG.py

# %% [markdown]
# ## DDPG (3 points total)
# We will be implementing the DDPG algorithm. The DDPG algorithm is a model free, off policy algorithm that combines the actor-critic architecture with the insights of DQN. The algorithm is as follows:
# ![DDPG](DDPG.png)
# Fill in both of the TODO in the `DDPG` class in DDPG.py

# %%
import wandb

wandb.login()

# %%
wandb.init(project="inverted-double-pendulum-ddpg")

# %%
import DDPG
import utils

t = DDPG.DDPG(env, model.Actor, model.Critic, use_wandb=True, save_path=utils.get_save_path("DDPG", "./runs/"))

t.train(10000, 100, 100, 1000, 100, 1)

# %% [markdown]
# Like what we did for the DQN, we can also animate one episode of the agent in the DoublePendulum environment.

# %%
total_rewards, frames = t.play_episode(0, True, 42, eval_env)
anim = animate(frames)
print(total_rewards)
HTML(anim.to_jshtml())

# %% [markdown]
# As we can see, the agent is able to balance the double pendulum and it eventually reaches the equilibrium. However this equilibrium is not a stable equilibrium, so lets see how this model performs with perturbations. To do this, we will perturbe the model every 49 steps with a large input of $\pm 0.75$ N to the cart. We will see how the model performs with this perturbation.

# %%
import torch

frames = []
scores = 0
(s, _), done, ret = eval_env.reset(seed=42), False, 0
t.actor.eval()
S = []
outputs = []
# s, r, terminated, truncated, info = eval_env.step(3)
i = 0
with torch.no_grad():
    while not done:
        # if random.random() < 0.1:
        #     action = random.randint(0,4)
        # else:
        frames.append(eval_env.render())
        output = t.actor(torch.tensor(s).unsqueeze(0).to("cpu").float())
        i += 1
        if i % 50 == 49:
            output += 0.75 * (np.sign(torch.randn_like(output)))
        s_prime, r, terminated, truncated, info = eval_env.step(output.cpu().numpy().squeeze(0))
        s = s_prime
        ret += r
        done = terminated or truncated

scores += ret

# %%
anim = animate(frames)
print(total_rewards)
HTML(anim.to_jshtml())

# %% [markdown]
# You should see that the model is able to recover from the perturbation and is able to balance the double pendulum.
